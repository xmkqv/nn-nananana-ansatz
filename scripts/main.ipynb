# %%
# %load_ext autoreload
# %autoreload 2

# %%
from env import env # environment variables
from pathlib import Path
from nn_nananana_ansatz.pyfig.pretty import print_tree
print_tree('../', ignore=['-dep-v2', '-dep', 'build'])
# Out:
# env_file: /home/m/code/nn-nananana-ansatz/scripts/.env
# Env(
#     test='xyz',
#     WANDB_USER='xmkqv',
#     WANDB_PROJECT='mc-hierachii',
#     WANDB_ENTITY='xmax1',
#     GITHUB_USER='xmkqv',
#     GITHUB_REPO='mc-hierachii',
#     GITHUB_TOKEN=SecretStr('**********')
# )
# environ test: True
# logger handler: 1
# logger level: INFO
# change level: os.environ["LOG: or "log"] = "LEVEL" or "level"
# levels: TRACE, DEBUG, INFO, SUCCESS, WARNING, ERROR, CRITICAL
# Ignoring:
# ['-dep-v2', '-dep', 'build']
# ╭────────────── Directory Tree ───────────────╮
# │ 📂 ]8;id=184128;file://../\../]8;;\                                      │
# │ ├── 📂 ]8;id=418566;file://../nn_nananana_ansatz\nn_nananana_ansatz]8;;\                   │
# │ │   ├── 📂 ]8;id=132785;file://../nn_nananana_ansatz/pyfig\pyfig]8;;\                            │
# │ │   │   ├── 📄 ]8;id=517646;file://../nn_nananana_ansatz/pyfig/-colors.css\-colors]8;;\]8;id=567127;file://../nn_nananana_ansatz/pyfig/-colors.css\.css]8;;\                  │
# │ │   │   ├── 🐍 ]8;id=105507;file://../nn_nananana_ansatz/pyfig/bug.py\bug]8;;\]8;id=796643;file://../nn_nananana_ansatz/pyfig/bug.py\.py]8;;\                       │
# │ │   │   ├── 🐍 ]8;id=472833;file://../nn_nananana_ansatz/pyfig/env_dist.py\env_dist]8;;\]8;id=125606;file://../nn_nananana_ansatz/pyfig/env_dist.py\.py]8;;\                  │
# │ │   │   ├── 🐍 ]8;id=411794;file://../nn_nananana_ansatz/pyfig/files.py\files]8;;\]8;id=412928;file://../nn_nananana_ansatz/pyfig/files.py\.py]8;;\                     │
# │ │   │   ├── 🐍 ]8;id=732453;file://../nn_nananana_ansatz/pyfig/log.py\log]8;;\]8;id=643955;file://../nn_nananana_ansatz/pyfig/log.py\.py]8;;\                       │
# │ │   │   ├── 🐍 ]8;id=425487;file://../nn_nananana_ansatz/pyfig/paths.py\paths]8;;\]8;id=1673;file://../nn_nananana_ansatz/pyfig/paths.py\.py]8;;\                     │
# │ │   │   ├── 🐍 ]8;id=16960;file://../nn_nananana_ansatz/pyfig/plugins.py\plugins]8;;\]8;id=980068;file://../nn_nananana_ansatz/pyfig/plugins.py\.py]8;;\                   │
# │ │   │   ├── 🐍 ]8;id=171818;file://../nn_nananana_ansatz/pyfig/pretty.py\pretty]8;;\]8;id=57803;file://../nn_nananana_ansatz/pyfig/pretty.py\.py]8;;\                    │
# │ │   │   ├── 🐍 ]8;id=250529;file://../nn_nananana_ansatz/pyfig/pydanmod.py\pydanmod]8;;\]8;id=715079;file://../nn_nananana_ansatz/pyfig/pydanmod.py\.py]8;;\                  │
# │ │   │   ├── 🐍 ]8;id=245149;file://../nn_nananana_ansatz/pyfig/pyfig.py\pyfig]8;;\]8;id=105169;file://../nn_nananana_ansatz/pyfig/pyfig.py\.py]8;;\                     │
# │ │   │   ├── 🐍 ]8;id=829865;file://../nn_nananana_ansatz/pyfig/schema.py\schema]8;;\]8;id=637106;file://../nn_nananana_ansatz/pyfig/schema.py\.py]8;;\                    │
# │ │   │   ├── 🐍 ]8;id=838961;file://../nn_nananana_ansatz/pyfig/typfig.py\typfig]8;;\]8;id=375402;file://../nn_nananana_ansatz/pyfig/typfig.py\.py]8;;\                    │
# │ │   │   └── 🐍 ]8;id=685449;file://../nn_nananana_ansatz/pyfig/utils.py\utils]8;;\]8;id=96235;file://../nn_nananana_ansatz/pyfig/utils.py\.py]8;;\                     │
# │ │   ├── 🐍 ]8;id=731422;file://../nn_nananana_ansatz/appfig.py\appfig]8;;\]8;id=61153;file://../nn_nananana_ansatz/appfig.py\.py]8;;\                        │
# │ │   ├── 🐍 ]8;id=532609;file://../nn_nananana_ansatz/cli.py\cli]8;;\]8;id=412152;file://../nn_nananana_ansatz/cli.py\.py]8;;\                           │
# │ │   ├── 🐍 ]8;id=630642;file://../nn_nananana_ansatz/hwat.py\hwat]8;;\]8;id=319230;file://../nn_nananana_ansatz/hwat.py\.py]8;;\                          │
# │ │   ├── 🐍 ]8;id=196476;file://../nn_nananana_ansatz/model.py\model]8;;\]8;id=96425;file://../nn_nananana_ansatz/model.py\.py]8;;\                         │
# │ │   ├── 🐍 ]8;id=371482;file://../nn_nananana_ansatz/systems.py\systems]8;;\]8;id=284272;file://../nn_nananana_ansatz/systems.py\.py]8;;\                       │
# │ │   ├── 🐍 ]8;id=780365;file://../nn_nananana_ansatz/torch_utils.py\torch_utils]8;;\]8;id=722338;file://../nn_nananana_ansatz/torch_utils.py\.py]8;;\                   │
# │ │   ├── 🐍 ]8;id=741575;file://../nn_nananana_ansatz/typer-cli.py\typer-cli]8;;\]8;id=339737;file://../nn_nananana_ansatz/typer-cli.py\.py]8;;\                     │
# │ │   └── 🐍 ]8;id=434362;file://../nn_nananana_ansatz/utils.py\utils]8;;\]8;id=241857;file://../nn_nananana_ansatz/utils.py\.py]8;;\                         │
# │ ├── 📂 ]8;id=61956;file://../scripts\scripts]8;;\                              │
# │ │   ├── 📂 ]8;id=518164;file://../scripts/data\data]8;;\                             │
# │ │   ├── 📂 ]8;id=777205;file://../scripts/wandb\wandb]8;;\                            │
# │ │   │   ├── 📂 ]8;id=211872;file://../scripts/wandb/latest-run\latest-run]8;;\                   │
# │ │   │   │   ├── 📂 ]8;id=453858;file://../scripts/wandb/latest-run/files\files]8;;\                    │
# │ │   │   │   │   ├── 📄 ]8;id=20891;file://../scripts/wandb/latest-run/files/config.yaml\config]8;;\]8;id=909095;file://../scripts/wandb/latest-run/files/config.yaml\.yaml]8;;\          │
# │ │   │   │   │   ├── 📄 ]8;id=736617;file://../scripts/wandb/latest-run/files/requirements.txt\requirements]8;;\]8;id=549921;file://../scripts/wandb/latest-run/files/requirements.txt\.txt]8;;\     │
# │ │   │   │   │   ├── 📄 ]8;id=186958;file://../scripts/wandb/latest-run/files/wandb-metadata.json\wandb-metadata]8;;\]8;id=224849;file://../scripts/wandb/latest-run/files/wandb-metadata.json\.json]8;;\  │
# │ │   │   │   │   └── 📄 ]8;id=811020;file://../scripts/wandb/latest-run/files/wandb-summary.json\wandb-summary]8;;\]8;id=357143;file://../scripts/wandb/latest-run/files/wandb-summary.json\.json]8;;\   │
# │ │   │   │   ├── 📂 ]8;id=748219;file://../scripts/wandb/latest-run/logs\logs]8;;\                     │
# │ │   │   │   │   ├── 📄 ]8;id=998087;file://../scripts/wandb/latest-run/logs/debug-internal.log\debug-internal]8;;\]8;id=343957;file://../scripts/wandb/latest-run/logs/debug-internal.log\.log]8;;\   │
# │ │   │   │   │   └── 📄 ]8;id=553912;file://../scripts/wandb/latest-run/logs/debug.log\debug]8;;\]8;id=750114;file://../scripts/wandb/latest-run/logs/debug.log\.log]8;;\            │
# │ │   │   │   ├── 📂 ]8;id=446925;file://../scripts/wandb/latest-run/tmp\tmp]8;;\                      │
# │ │   │   │   │   └── 📂 ]8;id=92008;file://../scripts/wandb/latest-run/tmp/code\code]8;;\                 │
# │ │   │   │   └── 📄 ]8;id=395127;file://../scripts/wandb/latest-run/run-u3d9b5k1.wandb\run-u3d9b5k1]8;;\]8;id=594953;file://../scripts/wandb/latest-run/run-u3d9b5k1.wandb\.wandb]8;;\       │
# │ │   │   ├── 📂 ]8;id=191150;file://../scripts/wandb/run-20230601_180158-blg529vj\run-20230601_180158-blg529vj]8;;\ │
# │ │   │   │   ├── 📂 ]8;id=358541;file://../scripts/wandb/run-20230601_180158-blg529vj/files\files]8;;\                    │
# │ │   │   │   │   ├── 📄 ]8;id=553084;file://../scripts/wandb/run-20230601_180158-blg529vj/files/config.yaml\config]8;;\]8;id=948220;file://../scripts/wandb/run-20230601_180158-blg529vj/files/config.yaml\.yaml]8;;\          │
# │ │   │   │   │   ├── 📄 ]8;id=440081;file://../scripts/wandb/run-20230601_180158-blg529vj/files/output.log\output]8;;\]8;id=733933;file://../scripts/wandb/run-20230601_180158-blg529vj/files/output.log\.log]8;;\           │
# │ │   │   │   │   ├── 📄 ]8;id=982779;file://../scripts/wandb/run-20230601_180158-blg529vj/files/requirements.txt\requirements]8;;\]8;id=957509;file://../scripts/wandb/run-20230601_180158-blg529vj/files/requirements.txt\.txt]8;;\     │
# │ │   │   │   │   ├── 📄 ]8;id=83484;file://../scripts/wandb/run-20230601_180158-blg529vj/files/wandb-metadata.json\wandb-metadata]8;;\]8;id=193740;file://../scripts/wandb/run-20230601_180158-blg529vj/files/wandb-metadata.json\.json]8;;\  │
# │ │   │   │   │   └── 📄 ]8;id=741501;file://../scripts/wandb/run-20230601_180158-blg529vj/files/wandb-summary.json\wandb-summary]8;;\]8;id=513313;file://../scripts/wandb/run-20230601_180158-blg529vj/files/wandb-summary.json\.json]8;;\   │
# │ │   │   │   ├── 📂 ]8;id=142695;file://../scripts/wandb/run-20230601_180158-blg529vj/logs\logs]8;;\                     │
# │ │   │   │   │   ├── 📄 ]8;id=515948;file://../scripts/wandb/run-20230601_180158-blg529vj/logs/debug-internal.log\debug-internal]8;;\]8;id=177214;file://../scripts/wandb/run-20230601_180158-blg529vj/logs/debug-internal.log\.log]8;;\   │
# │ │   │   │   │   └── 📄 ]8;id=780826;file://../scripts/wandb/run-20230601_180158-blg529vj/logs/debug.log\debug]8;;\]8;id=990590;file://../scripts/wandb/run-20230601_180158-blg529vj/logs/debug.log\.log]8;;\            │
# │ │   │   │   ├── 📂 ]8;id=133904;file://../scripts/wandb/run-20230601_180158-blg529vj/tmp\tmp]8;;\                      │
# │ │   │   │   │   └── 📂 ]8;id=532451;file://../scripts/wandb/run-20230601_180158-blg529vj/tmp/code\code]8;;\                 │
# │ │   │   │   └── 📄 ]8;id=767984;file://../scripts/wandb/run-20230601_180158-blg529vj/run-blg529vj.wandb\run-blg529vj]8;;\]8;id=107453;file://../scripts/wandb/run-20230601_180158-blg529vj/run-blg529vj.wandb\.wandb]8;;\       │
# │ │   │   ├── 📂 ]8;id=856709;file://../scripts/wandb/run-20230601_183044-4btu5tor\run-20230601_183044-4btu5tor]8;;\ │
# │ │   │   │   ├── 📂 ]8;id=644603;file://../scripts/wandb/run-20230601_183044-4btu5tor/files\files]8;;\                    │
# │ │   │   │   │   ├── 📄 ]8;id=354646;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/config.yaml\config]8;;\]8;id=122743;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/config.yaml\.yaml]8;;\          │
# │ │   │   │   │   ├── 📄 ]8;id=417976;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/requirements.txt\requirements]8;;\]8;id=243611;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/requirements.txt\.txt]8;;\     │
# │ │   │   │   │   ├── 📄 ]8;id=47418;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/wandb-metadata.json\wandb-metadata]8;;\]8;id=777884;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/wandb-metadata.json\.json]8;;\  │
# │ │   │   │   │   └── 📄 ]8;id=477887;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/wandb-summary.json\wandb-summary]8;;\]8;id=698692;file://../scripts/wandb/run-20230601_183044-4btu5tor/files/wandb-summary.json\.json]8;;\   │
# │ │   │   │   ├── 📂 ]8;id=408159;file://../scripts/wandb/run-20230601_183044-4btu5tor/logs\logs]8;;\                     │
# │ │   │   │   │   ├── 📄 ]8;id=137326;file://../scripts/wandb/run-20230601_183044-4btu5tor/logs/debug-internal.log\debug-internal]8;;\]8;id=617884;file://../scripts/wandb/run-20230601_183044-4btu5tor/logs/debug-internal.log\.log]8;;\   │
# │ │   │   │   │   └── 📄 ]8;id=325521;file://../scripts/wandb/run-20230601_183044-4btu5tor/logs/debug.log\debug]8;;\]8;id=948048;file://../scripts/wandb/run-20230601_183044-4btu5tor/logs/debug.log\.log]8;;\            │
# │ │   │   │   ├── 📂 ]8;id=509900;file://../scripts/wandb/run-20230601_183044-4btu5tor/tmp\tmp]8;;\                      │
# │ │   │   │   │   └── 📂 ]8;id=380385;file://../scripts/wandb/run-20230601_183044-4btu5tor/tmp/code\code]8;;\                 │
# │ │   │   │   └── 📄 ]8;id=205631;file://../scripts/wandb/run-20230601_183044-4btu5tor/run-4btu5tor.wandb\run-4btu5tor]8;;\]8;id=584795;file://../scripts/wandb/run-20230601_183044-4btu5tor/run-4btu5tor.wandb\.wandb]8;;\       │
# │ │   │   ├── 📂 ]8;id=745133;file://../scripts/wandb/run-20230601_185035-uv3tsqin\run-20230601_185035-uv3tsqin]8;;\ │
# │ │   │   │   ├── 📂 ]8;id=970781;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files\files]8;;\                    │
# │ │   │   │   │   ├── 📄 ]8;id=5074;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/config.yaml\config]8;;\]8;id=181303;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/config.yaml\.yaml]8;;\          │
# │ │   │   │   │   ├── 📄 ]8;id=908984;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/output.log\output]8;;\]8;id=76060;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/output.log\.log]8;;\           │
# │ │   │   │   │   ├── 📄 ]8;id=711682;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/requirements.txt\requirements]8;;\]8;id=506830;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/requirements.txt\.txt]8;;\     │
# │ │   │   │   │   ├── 📄 ]8;id=906864;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/wandb-metadata.json\wandb-metadata]8;;\]8;id=622658;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/wandb-metadata.json\.json]8;;\  │
# │ │   │   │   │   └── 📄 ]8;id=797468;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/wandb-summary.json\wandb-summary]8;;\]8;id=590335;file://../scripts/wandb/run-20230601_185035-uv3tsqin/files/wandb-summary.json\.json]8;;\   │
# │ │   │   │   ├── 📂 ]8;id=736719;file://../scripts/wandb/run-20230601_185035-uv3tsqin/logs\logs]8;;\                     │
# │ │   │   │   │   ├── 📄 ]8;id=333181;file://../scripts/wandb/run-20230601_185035-uv3tsqin/logs/debug-internal.log\debug-internal]8;;\]8;id=89787;file://../scripts/wandb/run-20230601_185035-uv3tsqin/logs/debug-internal.log\.log]8;;\   │
# │ │   │   │   │   └── 📄 ]8;id=638523;file://../scripts/wandb/run-20230601_185035-uv3tsqin/logs/debug.log\debug]8;;\]8;id=959623;file://../scripts/wandb/run-20230601_185035-uv3tsqin/logs/debug.log\.log]8;;\            │
# │ │   │   │   ├── 📂 ]8;id=478468;file://../scripts/wandb/run-20230601_185035-uv3tsqin/tmp\tmp]8;;\                      │
# │ │   │   │   │   └── 📂 ]8;id=786135;file://../scripts/wandb/run-20230601_185035-uv3tsqin/tmp/code\code]8;;\                 │
# │ │   │   │   └── 📄 ]8;id=382911;file://../scripts/wandb/run-20230601_185035-uv3tsqin/run-uv3tsqin.wandb\run-uv3tsqin]8;;\]8;id=288124;file://../scripts/wandb/run-20230601_185035-uv3tsqin/run-uv3tsqin.wandb\.wandb]8;;\       │
# │ │   │   ├── 📂 ]8;id=634169;file://../scripts/wandb/run-20230601_185440-u3d9b5k1\run-20230601_185440-u3d9b5k1]8;;\ │
# │ │   │   │   ├── 📂 ]8;id=276959;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files\files]8;;\                    │
# │ │   │   │   │   ├── 📄 ]8;id=371283;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/config.yaml\config]8;;\]8;id=592240;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/config.yaml\.yaml]8;;\          │
# │ │   │   │   │   ├── 📄 ]8;id=536173;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/requirements.txt\requirements]8;;\]8;id=375519;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/requirements.txt\.txt]8;;\     │
# │ │   │   │   │   ├── 📄 ]8;id=644440;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/wandb-metadata.json\wandb-metadata]8;;\]8;id=303779;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/wandb-metadata.json\.json]8;;\  │
# │ │   │   │   │   └── 📄 ]8;id=939492;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/wandb-summary.json\wandb-summary]8;;\]8;id=88578;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/files/wandb-summary.json\.json]8;;\   │
# │ │   │   │   ├── 📂 ]8;id=876397;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/logs\logs]8;;\                     │
# │ │   │   │   │   ├── 📄 ]8;id=523021;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/logs/debug-internal.log\debug-internal]8;;\]8;id=592307;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/logs/debug-internal.log\.log]8;;\   │
# │ │   │   │   │   └── 📄 ]8;id=267717;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/logs/debug.log\debug]8;;\]8;id=994173;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/logs/debug.log\.log]8;;\            │
# │ │   │   │   ├── 📂 ]8;id=254366;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/tmp\tmp]8;;\                      │
# │ │   │   │   │   └── 📂 ]8;id=635693;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/tmp/code\code]8;;\                 │
# │ │   │   │   └── 📄 ]8;id=424470;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/run-u3d9b5k1.wandb\run-u3d9b5k1]8;;\]8;id=634583;file://../scripts/wandb/run-20230601_185440-u3d9b5k1/run-u3d9b5k1.wandb\.wandb]8;;\       │
# │ │   │   ├── 📄 ]8;id=746716;file://../scripts/wandb/debug-cli.m.log\debug-cli]8;;\]8;id=324955;file://../scripts/wandb/debug-cli.m.log\.m.log]8;;\              │
# │ │   │   ├── 📄 ]8;id=399782;file://../scripts/wandb/debug-internal.log\debug-internal]8;;\]8;id=521639;file://../scripts/wandb/debug-internal.log\.log]8;;\           │
# │ │   │   └── 📄 ]8;id=107;file://../scripts/wandb/debug.log\debug]8;;\]8;id=722690;file://../scripts/wandb/debug.log\.log]8;;\                    │
# │ │   ├── 🐍 ]8;id=469584;file://../scripts/appfig.py\appfig]8;;\]8;id=16810;file://../scripts/appfig.py\.py]8;;\                        │
# │ │   ├── 🐍 ]8;id=867019;file://../scripts/env.py\env]8;;\]8;id=166547;file://../scripts/env.py\.py]8;;\                           │
# │ │   ├── 🐍 ]8;id=257298;file://../scripts/lightning.py\lightning]8;;\]8;id=804366;file://../scripts/lightning.py\.py]8;;\                     │
# │ │   ├── 📄 ]8;id=857015;file://../scripts/main.ipynb\main]8;;\]8;id=742352;file://../scripts/main.ipynb\.ipynb]8;;\                       │
# │ │   ├── 📄 ]8;id=725649;file://../scripts/tmp4gc1tcbv\tmp4gc1tcbv]8;;\                      │
# │ │   ├── 📄 ]8;id=86493;file://../scripts/tmpmsb7yqta\tmpmsb7yqta]8;;\                      │
# │ │   └── 📄 ]8;id=127173;file://../scripts/tmpp_o0velt\tmpp_o0velt]8;;\                      │
# │ ├── 📄 ]8;id=801046;file://../pdm.lock\pdm]8;;\]8;id=72961;file://../pdm.lock\.lock]8;;\                             │
# │ ├── 📄 ]8;id=656080;file://../pyproject.toml\pyproject]8;;\]8;id=392573;file://../pyproject.toml\.toml]8;;\                       │
# │ └── 📄 ]8;id=530927;file://../README.md\README]8;;\]8;id=43372;file://../README.md\.md]8;;\                            │
# ╰─────────────────────────────────────────────╯

# %% [markdown]
# Geometries of molecular oxygen in different spin states and oxidation states

# %% [markdown]
# O2, mult3	1.2075
# O2, mult1	1.2255
# O2+, mult2	1.1164

# %%
from rich.pretty import pprint
from rich import print

from nn_nananana_ansatz.pyfig.pyfig import DEVICES, DTYPES, RUNMODE
from nn_nananana_ansatz.pyfig.paths import Paths
from nn_nananana_ansatz.pyfig.plugins import Logger, Opt, OPTS, LOGMODE, RUNTYPE
from nn_nananana_ansatz.pyfig.utils import get_attrs

from nn_nananana_ansatz.systems import System
from appfig import Ansatzcfg, Walkers, Pyfig

# %%
class Pyfig(Pyfig):

	seed: int           	= 42
	debug: bool         	= False

	device: DEVICES     	= DEVICES.gpu
	dtype: DTYPES          	= DTYPES.float32
	
	paths: Paths = Paths(
		project         = 'hwat',
		exp_name        = 'test',
		run_name        = 'run.py',
		exp_data_dir    = 'data',
	)

	mode: RUNMODE       	= RUNMODE.train  # adam, sgd

	n_epoch: int      		= 100
	n_step: int      		= 100

	loss: str        		= 'vmc'  # orb_mse, vmc

	logger: Logger      = Logger(
		exp_name 		= paths.exp_name, 
		entity			= env.WANDB_ENTITY,
		project			= paths.project,
		n_log_metric	= 2,
		n_log_state		= -1,
		run_path		= paths.run_path,
        runtype         = RUNTYPE.runs,
		exp_data_dir	= paths.exp_data_dir,
	)

	opt: Opt         	= Opt(
		name = OPTS.AdamW,
	)

	walkers: Walkers = Walkers(
		n_b = 64,
        n_equil_step= 10 # DEBUGGING
	)

	system: System = System( # validation issue when nested, don't nest
	a =    [[0.0, 0.0, 0.0], [1.2075, 0.0, 0.0]],
	a_z =  [8, 8],
	charge = 0,
	spin = 2, # total spin, unparse
	)
	
	ansatzcfg: Ansatzcfg = Ansatzcfg(
		n_l 	= 3,
		ke_method 	= 'grad_grad', # inefficient, can do jit compiled version
	)

c = Pyfig( # edit here also

	seed= 1,
	
	ansatzcfg= Ansatzcfg(
		n_l 	= 2,
		ke_method 	= 'grad_grad',
	),
)

from nn_nananana_ansatz.pyfig.utils import print_maybe_inspect

for k,v in c.items():
	print(k, v)
# attrs = get_attrs(c)
# pprint(attrs)

# attrs = get_attrs(c.walkers)
# pprint(attrs)
# Out:
# ansatzcfg
# Ansatzcfg(
#     n_l=2,
#     n_sv=32,
#     n_pv=16,
#     n_fb=3,
#     n_det=4,
#     n_final_out=1,
#     terms_s_emb=['ra', 'ra_len'],
#     terms_p_emb=['rr', 'rr_len'],
#     ke_method='grad_grad'
# )
# debug False
# device cuda
# dtype float32
# logger
# Logger(
#     entity='xmax1',
#     project='hwat',
#     exp_name='test',
#     run_path=PosixPath('projects/hwat/run.py'),
#     exp_data_dir=PosixPath('exp/exp_data'),
#     log_interval=10,
#     save_interval=100,
#     resume_checkpoint='',
#     n_log_metric=2,
#     n_log_state=-1,
#     log_mode=<LOGMODE.online: 'online'>,
#     log_model=True,
#     runtype=<RUNTYPE.runs: 'runs'>,
#     job_type='dev'
# )
# loss vmc
# mode train
# n_epoch 100
# n_step 100
# opt
# Opt(
#     name=<OPTS.AdamW: 'AdamW'>,
#     lr=0.001,
#     init_lr=0.001,
#     betas=[0.9, 0.999],
#     beta=0.9,
#     warm_up=100,
#     eps=0.0001,
#     weight_decay=0.0,
#     hessian_power=1.0,
#     lr_anneal_steps=1000,
#     ema_rate='0.9999'
# )
# paths
# Paths(
#     project='hwat',
#     exp_name='test',
#     run_name=PosixPath('run.py'),
#     env_file=PosixPath('/home/m/code/nn-nananana-ansatz/nn_nananana_ansatz/pyfig/.env'),
#     lo_ve_path='',
#     exp_id='c70ed0c80f',
#     home=PosixPath('.'),
#     exp_dir=PosixPath('exp')
# )
# seed 1
# system
# System(
#     a=ndarray([[0.    , 0.    , 0.    ],
#          [0.    , 1.2075, 0.    ]]),
#     a_z=ndarray([8, 8]),
#     charge=0,
#     spin=2
# )
# walkers
# Walkers(n_b=64, n_corr=20, n_equil_step=10, acc_target=0.5, init_data_scale=0.1)

# %%
# leave for now
# from pyfig.cli import TyperSource
# ts = TyperSource(c)
# ts.write()
# print(ts)

# %%
# import pandas as pd
# data_explore = ex.reshape(ex.shape[:3], -1) / 255.
# df = pd.DataFrame.from_dict({f"dim_{i}": data_explore[:100, i] for i in range(100)})
# df.head()
# import pygwalker as pyg
# gwalker = pyg.walk(df)

# %%
from nn_nananana_ansatz.hwat import Scf # https://github.com/pyscf wrapper

scf = Scf(system= c.system)
scf.init_app()
print(scf)

# electronic spin
# define the diffence between spin total, lots [:
# <S^2> = 4.4408921e-16  2S+1 = 1
# Out:
# pyfig:pyscf:
# converged SCF energy = -144.084750676126  <S^2> = 2.0008124  2S+1 = 3.0005416
# app:init_app: mo_coef shape: (2, 10, 10)
# **** MO energy ****
#                              alpha | beta                alpha | beta
# MO #1   energy= -21.0284314415787  | -20.9911041542446  occ= 1 | 1
# MO #2   energy= -20.9471190199291  | -20.9065291461556  occ= 1 | 1
# MO #3   energy= -2.40494141278155  | -2.32225951696211  occ= 1 | 1
# MO #4   energy= -1.32132963072916  | -1.11969361990839  occ= 1 | 1
# MO #5   energy= -1.32132963072916  | -1.11969361990839  occ= 1 | 1
# MO #6   energy= -0.98730471246679  | -0.788701048233836 occ= 1 | 1
# MO #7   energy= -0.859144110331425 | -0.757484628916065 occ= 1 | 1
# MO #8   energy= -0.115754124642644 | 0.680443753354026  occ= 1 | 0
# MO #9   energy= -0.115754124642641 | 0.680443753354028  occ= 1 | 0
# MO #10  energy= 3.24064806202366   | 3.35909272248915   occ= 0 | 0
#
# To work with the spin densities directly, `use mulliken_meta_spin()` only printing them here.
#
#  ** Mulliken spin pop alpha/beta on meta-lowdin orthogonal AOs **
#  ** Mulliken Spin Density (per atom)  **
# spin density of  0 O =      1.00000
# spin density of  1 O =      1.00000
#  ** Mulliken pop alpha/beta on meta-lowdin orthogonal AOs **
#  ** Mulliken atomic charges   ( Nelec_alpha | Nelec_beta ) **
# charge of  0O =      0.00000  (     4.50000      3.50000 )
# charge of  1O =      0.00000  (     4.50000      3.50000 )
# Dipole moment(X, Y, Z, Debye): -0.00000,  0.00000, -0.00000
# UHF object of <class 'pyscf.scf.uhf.UHF'>
# <nn_nananana_ansatz.hwat.Scf object at 0x7f7777b48160>

# %%
from copy import deepcopy

import torch
from torch.utils.data import DataLoader
from functorch import make_functional_with_buffers, vmap

from nn_nananana_ansatz.hwat import PyfigDataset, Ansatz



# CONVERT TO TORCH
dtype = dict(float32= torch.float32, float64= torch.float64, float16= torch.float16).get(c.dtype)
device = torch.device(c.device)
system_th = get_attrs(c.system)
system_th.update(dict(
    a= torch.tensor(system_th['a'], dtype= dtype, device= device), 
    a_z= torch.tensor(system_th['a_z'], dtype= dtype, device= device)
))
mo_coef = torch.tensor(scf.mo_coef, device=device, dtype=dtype)


print(f"""
device: {device}
dtype: {dtype}
""")
# INITIALISE THE MODEL
model = Ansatz(**system_th, **get_attrs(c.ansatzcfg), mol= None, mo_coef= mo_coef).to(device=device, dtype= dtype)
model_to_fn: torch.nn.Module = deepcopy(model)
model_fn, param, buffer = make_functional_with_buffers(model_to_fn)
model_fn_vmap = vmap(model_fn, in_dims=(None, None, 0))
del model
model = Ansatz(**system_th, **get_attrs(c.ansatzcfg), mol= scf.mol, mo_coef= mo_coef).to(device=device, dtype= dtype)

# INITIALISE THE DATASET
dataset = PyfigDataset(c, system= c.system, walkers= c.walkers)
def custom_collate(batch):
	return batch[0]
dataloader = DataLoader(dataset, batch_size= 1, collate_fn= custom_collate)  # c.data.n_b otherwise because of the internal sampler

# INITIALISE THE OPTIMISER
from torch.optim import Optimizer
from nn_nananana_ansatz.utils import get_opt
opt: Optimizer = get_opt(**get_attrs(c.opt))(model.parameters())

# TORCH SETTINGS https://jamesmccaffrey.wordpress.com/2019/01/23/pytorch-train-vs-eval-mode/
# not important 
model.train()
if 'eval' in c.mode:
    model.eval()

# wrap up
dataloader.dataset.init_dataset(c, device= device, dtype= dtype, model= model)
# Out:
# device: cuda
# dtype: torch.float32
# model fb layers:
#  [(32, 32), (128, 32), (128, 32), (128, 32)] [(4, 16), (16, 16), (16, 16), (16, 16)]
# model fb layers:
#  [(32, 32), (128, 32), (128, 32), (128, 32)] [(4, 16), (16, 16), (16, 16), (16, 16)]
# hwat:dataset: init
# hwat:dataset:init: center_points
# tensor([[0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000]], dtype=torch.float64)
# dataset:len  100
# dataset:init_dataset: data  torch.Size([64, 16, 3]) torch.float32 cuda:0
# /home/m/code/nn-nananana-ansatz/.venv/lib/python3.10/site-packages/torch/_functorch/deprecated.py:101: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.make_functional_with_buffers is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.func.functional_call instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('make_functional_with_buffers', 'torch.func.functional_call')
# /home/m/code/nn-nananana-ansatz/.venv/lib/python3.10/site-packages/torch/_functorch/deprecated.py:58: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# |    |     deltar |        acc |      diff |
# |---:|-----------:|-----------:|----------:|
# |  0 | 0.001      | 0.646133   | 0.0535234 |
# |  1 | 0.00215443 | 0.600899   | 0.0702266 |
# |  2 | 0.00464159 | 0.653399   | 0.0502422 |
# |  3 | 0.01       | 0.663086   | 0.0440078 |
# |  4 | 0.0215444  | 0.639219   | 0.051875  |
# |  5 | 0.0464159  | 0.531875   | 0.128125  |
# |  6 | 0.1        | 0.5225     | 0.1375    |
# |  7 | 0.215443   | 0.253008   | 0.406992  |
# |  8 | 0.464159   | 0.0389453  | 0.621055  |
# |  9 | 1          | 0.00699219 | 0.653008  |
# dataset:init_dataset deltar  tensor([0.0100], device='cuda:0')
# equil  0  acc  0.7886718511581421  deltar  0.010000000707805157
# dataset:init_dataset sampler is pretraining  False
# dataset:init_dataset
# data torch.Size([64, 16, 3]) cuda:0 torch.float32 tensor(0.1980, device='cuda:0') tensor(0.7173, device='cuda:0')
# acc torch.Size([1]) cuda:0 torch.float32 tensor(0.6352, device='cuda:0') tensor(nan, device='cuda:0')
# deltar torch.Size([1]) cuda:0 torch.float32 tensor(0.0520, device='cuda:0') tensor(nan, device='cuda:0')
# p_start torch.Size([64]) cuda:0 torch.float32 tensor(0., device='cuda:0') tensor(0., device='cuda:0')

# %%
import wandb
import os

os.environ['WANDB_NOTEBOOK_NAME']='main'
wandb.init( # https://wandb.ai/
    project = env.WANDB_PROJECT,
    entity= env.WANDB_ENTITY,
    name= c.logger.exp_name,
    mode= c.logger.log_mode,
    tags= [c.logger.runtype]
)
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find main.
# wandb: Currently logged in as: xmax1. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/home/m/code/nn-nananana-ansatz/scripts/wandb/run-20230601_194029-dww34eyx</code>
# Syncing run <strong><a href='https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx' target="_blank">test</a></strong> to <a href='https://wandb.ai/xmax1/mc-hierachii' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xmax1/mc-hierachii' target="_blank">https://wandb.ai/xmax1/mc-hierachii</a>
#  View run at <a href='https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx' target="_blank">https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from pydantic import BaseModel, Field
from torch import Tensor

class Variables(BaseModel):
	params: dict[str, Tensor] = Field(None, description= 'model parameters')
	grads: dict[str, Tensor] = None
	loss: Tensor = None
	e: Tensor = None
	ke: Tensor = None
	pe: Tensor = None

	class Config:
		arbitrary_types_allowed = True

v = Variables()
v.dict()
# Out:
# {'params': None, 'grads': None, 'loss': None, 'e': None}

# %%
from nn_nananana_ansatz.pyfig.utils import compute_metrix
from nn_nananana_ansatz.torch_utils import npify_tree
from nn_nananana_ansatz.hwat import loss_fn, loss_fn_pretrain

from appfig import compute_grads, update

from typing import Callable

class Step(BaseModel):

	model: torch.nn.Module
	opt: torch.optim.Optimizer

	step_initial: int = 0

	def _grads_to_model(self, grads: dict):
		for i, (k, p) in enumerate(self.model.named_parameters()):
			g = grads.get(k)
			if g is None: 
				g = torch.zeros_like(p)
			if p.grad is None:
				p.grad = torch.zeros_like(p)
			else:
				p.grad.copy_(g)

	def update(self) -> None:
		grads = grads or {k: p.grad for k, p in model.named_parameters()}
		self._grads_to_model(grads)
		opt.step()
	
	def loss_fn(self, data: torch.Tensor) -> Variables:
		v = Variables()
		raise NotImplementedError
	
	@staticmethod
	def log(v_d: dict|Variables) -> None:	
		if step % c.logger.n_log_metric == 0:
			if isinstance(v_d, Variables):
				v_d = v_d.dict()
			v_cpu_d: dict = npify_tree(v_d)
			v_metrix: dict = compute_metrix(v_cpu_d)
			wandb.log(v_metrix)

	def __call__(self) -> dict:
		model.zero_grad(set_to_none= True)
		v_d = self.loss_fn(data)
		v_d.update((('params', {k:p.detach() for k,p in model.named_parameters()}),))  # collecting for 
		return v_d

pretrainer = Step(loss_fn= loss_fn_pretrain)
trainer = Step(loss_fn= loss_fn)

v_cpu_d = dict()
for step, loader_d in enumerate(dataloader, start= 1):  # dataloader contains sampling loop

	data = loader_d['data'].to(device= device, dtype= dtype)




wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>e.mean</td><td>▆▇██▇█▇▇▇▆▆▆▅▅▅▅▅▅▅▄▄▃▄▃▄▃▃▄▂▃▂▁▂▁▂▂▁▁▁▁</td></tr><tr><td>e.std</td><td>▂▃▁▂▂▁▁▁▁▃▁▂▂▁▃▁▂▂▁▃█▆▂▃▁▃▃▂▂▁▂▂▂▃▂▃▁▂▂▂</td></tr><tr><td>grads/p_lay.0.bias.mean</td><td>█▂▄▄▄▁▄▄▄▆▁▂▄▄▄▁▂▅▄▃▄▃▄▂▃▃▄▃▄▃▃▄▄▃▄▄▁▄▃▂</td></tr><tr><td>grads/p_lay.0.bias.std</td><td>▆▆▃▃▄▅▃▃▄█▂▃▆▂▂▁▁▃▂▁▃▃▄▂▂▂▂▆▂▂▃▃▂▂▆▄▂▅▃▂</td></tr><tr><td>grads/p_lay.0.weight.mean</td><td>▆▁█▆▆▅▅▇▁▆▆▅▆▆▆▅▅▆▅▄▇▄▅▅▅▆▅▅▅▄▅▆▆▅▅▅▅▇▆▅</td></tr><tr><td>grads/p_lay.0.weight.std</td><td>▇▆▄▇██▅▆█▆▇▄▄▅▃▂▃▄▃▃▄▅▄▂▃▂▃▄▄▂▃▄▂▂▃▃▄▅▄▁</td></tr><tr><td>grads/p_lay.1.bias.mean</td><td>▃▁▂▃▂▁▄▃▃█▂▂▄▄▃▄▂▃▁▄▃▃▄▄▃▃▃▂▁▄▄▃▅▄▂▂▂▂▄▃</td></tr><tr><td>grads/p_lay.1.bias.std</td><td>▄▄▄▄▅▃▂▄▃█▆▃▅▄▄▃▄▃▃▁▂▄▅▄▁▃▅▄▁▃▅▂▄▃▅▅▂▅▃▂</td></tr><tr><td>grads/p_lay.1.weight.mean</td><td>▄▃▄▁▁▃▄▂▇▆▅▂▄▇▄▂▄▂▃▆▅▄▄▄▅▄▄▆▄▄▆▃▄▅▄█▆▇▃▅</td></tr><tr><td>grads/p_lay.1.weight.std</td><td>██▅█▇▆▃▇▆▅█▄▅▆▄▄▃▆▅▃▅▅▄▄▂▃▄▇▄▃▅▆▅▃▄▆▆▆▅▁</td></tr><tr><td>grads/p_lay.2.bias.mean</td><td>▄▄▃▅▃▄▃▃▅█▂▂▃▅▂▅▂▃▄▄▄▃▅▄▄▃▂▁▃▂▄▄▆▇▁▃▄▂▄▃</td></tr><tr><td
�▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>grads/w_spin_d.bias.mean</td><td>▅█▂▃▃▃▃▃▂▃▂▃▂▃▆▁▁▂▂▂▂▃▂▃▃▃▃▃▂▃▂▂▄▃▁▅▂▂▂▃</td></tr><tr><td>grads/w_spin_d.bias.std</td><td>▄▆▃▃▃▂▁▂▃▂▃▂▂▂█▃▄▂▁▂▂▁▂▂▂▁▁▄▁▂▁▄▂▂▅▆▁▁▂▁</td></tr><tr><td>grads/w_spin_d.weight.mean</td><td>▂▄▇▅▅▆▅▄▆▃▇▅▆▇▂█▆▇▆▇▅▅▄▆▅▆▃▅▆▆▆█▅▅█▁▆▆▅▅</td></tr><tr><td>grads/w_spin_d.weight.std</td><td>▅▄▂▅▄ ...
#  View run <strong style="color:#cdcd00">test</strong> at: <a href='https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx' target="_blank">https://wandb.ai/xmax1/mc-hierachii/runs/dww34eyx</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230601_194029-dww34eyx/logs</code>

# %%
import torch
import optree

def npify_tree(v: dict|list, return_flat_with_spec=False):
	if not isinstance(v, dict|list):
		if isinstance(v, torch.Tensor):
			v: torch.Tensor
			v: torch.Tensor = v.detach().cpu().numpy()
		return v
	leaves, treespec = optree.tree_flatten(v)
	leaves = [v.detach().cpu().numpy() if isinstance(v, torch.Tensor) else v for v in leaves]
	if return_flat_with_spec:
		return leaves, treespec
	return optree.tree_unflatten(treespec=treespec, leaves=leaves)

x = npify_tree(v_d)
x
# Out:
# {'loss': -0.811373233795166,
#  'e': array([ -81.31462 , -116.08135 ,  -72.30799 , -104.7206  ,  -78.04805 ,
#          -97.44184 ,  -97.27993 , -103.2823  , -142.6241  ,  -79.47188 ,
#          -66.04694 , -128.51404 , -175.66748 ,  -87.921555,  -75.15442 ,
#          -92.746994,  -59.341393,  -55.477875,  -98.31819 , -147.50862 ,
#         -104.248566, -105.56569 ,  -61.728462, -107.47181 ,  -94.51627 ,
#          -71.905396, -103.34146 , -112.97868 , -144.11095 , -144.73555 ,
#          -82.690254,  -76.70642 ,  -53.617256, -103.224464,  -56.737007,
#         -169.74649 , -152.4171  , -123.87967 ,  -87.79291 ,  -76.9225  ,
#          -95.40061 , -141.0791  ,  -67.4262  ,  -94.62993 ,  -90.830086,
#          -94.06549 ,  -92.69713 ,  -97.619965, -101.88224 ,  -95.07445 ,
#          -76.05632 ,  -55.18609 ,  -88.05678 ,  -91.87558 , -204.82239 ,
#         -142.63199 ,  -73.40776 , -197.06879 , -110.65987 , -118.390144,
#         -108.93739 , -101.17929 , -103.73135 , -123.43054 ], dtype=float32),
#  'pe': array([-107.3979  , -192.4958  , -112.53186 , -164.60947 , -116.98636 ,
#         -133.11092 , -178.81183 , -170.50128 , -196.08067 , -135.47833 ,
#         -135.48361 , -207.57361 , -307.32996 , -135.4682  , -138.42285 ,
#         -124.134735, -134.73238 , -167.71194 , -195.61176 , -276.07092 ,
#         -171.68594 , -183.5886  , -116.06207 , -169.06892 , -147.29279 ,
#         -164.92412 , -188.24731 , -174.94688 , -237.50568 , -274.64557 ,
#         -140.80533 , -145.8823  ,  -95.22031 , -230.36688 , -139.03345 ,
#           -0.00129012, -0.01752346],
#          ...,
#          [ 0.07324612, -0.05475288,  0.06972809, ...,  0.03540107,
#           -0.06222253, -0.05027357],
#          [ 0.05814559, -0.06221646,  0.05573452, ...,  0.01624742,
#           -0.02042308,  0.01244126],
#          [ 0.03251225, -0.01648351,  0.02594098, ...,  0.03158218,
#           -0.00941995, -0.01460193]], dtype=float32),
#   's_lay.1.bias': array([ 4.93354490e-03, -7.96905346e-03,  3.51592153e-02, -1.43382838e-02,
#           2.85754185e-02,  7.93294236e-03,  4.37152106e-04, -1.21620886e-01,
#           1.14110082e-01,  7.69091491e-03,  3.63884820e-03,  3.75380106e-02,
#          -2.65241452e-02, -6.11444637e-02, -3.67456153e-02,  1.00541366e-02,
#          -1.33897075e-02,  1.40110925e-02, -1.01751098e-02, -3.23725678e-02,
#          -1.19285211e-02,  2.21173558e-02, -2.82356776e-02,  2.64297165e-02,
#          -1.51877096e-02,  3.80930826e-02, -4.46694531e-02, -3.11509650e-02,
#          -5.81655046e-03,  4.06727886e-05, -2.15636920e-02,  1.08349985e-02],
#         dtype=float32),
#   's_lay.2.weight': array([[ 0.03408868, -0.03934313,  0.01187757, ..., -0.04828857,
#           -0.05910478, -0.02061568],
#          [ 0.0127205 , -0.01563305,  0.00787919, ...,  0.03453071,
#            0.00886963, -0.00800095],
#          [-0.03794266,  0.03435493, -0.04685238, ...,  0.03705977,
#            0.02898913, -0.01807253],
#          ...,
#          [ 0.04559756, -0.03977878,  0.04877109, ...,  0.03672611,
#           -0.0381875 , -0.04632911],
#          [ 0.07254125, -0.08563595,  0.05627825, ..., -0.02349858,
#           -0.02684898,  0.02452068],
#          [ 0.01627691, -0.00593201,  0.00344746, ..., -0.00231483,
#           -0.03155338, -0.04114545]], dtype=float32),
#   's_lay.2.bias': array([-0.02656801, -0.00104939,  0.02900703, -0.04392878,  0.02890853,
#           0.00714219, -0.01089561, -0.04643781,  0.07739075, -0.00098445,
#          -0.02539244,  0.01175761, -0.01686097, -0.0472791 , -0.04260523,
#           0.01608794, -0.0104729 ,  0.02614312, -0.01744055, -0.03250628,
#          -0.00767649,  0.02275329, -0.00392794,  0.01179875, -0.01926476,
#           0.03118713, -0.01892597,  0.01576232, -0.01517626, -0.00443662,
#          -0.03286251,  0.01492414], dtype=float32),
#   's_lay.3.weight': array([[ 0.01543883, -0.03896254,  0.00309466, ..., -0.03422451,
#           -0.05773987, -0.02506242],
#          [ 0.01676845, -0.0527643 ,  0.03331252, ...,  0.07422311,
#            0.03744236, -0.00704295],
#          [-0.01778986,  0.01703323, -0.01852167, ...,  0.02003087,
#            0.01359906, -0.01796144],
#          ...,
#          [ 0.02624144, -0.03435056,  0.03693351, ...,  0.00239285,
#           -0.02792346, -0.00177236],
#          [ 0.08181331, -0.11945668,  0.08236766, ..., -0.04481962,
#           -0.06802142,  0.03603888],
#          [-0.00940827, -0.01319334,  0.00874383, ...,  0.05401937,
#            0.01414426, -0.06689227]], dtype=float32),
#   's_lay.3.bias': array([-0.01988853, -0.02006091,  0.00881757, -0.01314959,  0.01697158,
#         dtype=float32),
#   's_lay.1.weight': array([[-0.04767184, -0.00486442,  0.02561334, ..., -0.04104629,
#           -0.04173765,  0.01838196],
#          [ 0.05693433,  0.07730795,  0.00117833, ..., -0.01723072,
#           -0.02405868, -0.09615187],
#          [ 0.03279166,  0.03592126, -0.06088042, ..., -0.00649181,
#           -0.03665671,  0.07688691],
#          ...,
#          [-0.04410011, -0.03608143, -0.04528499, ...,  0.07200557,
#           -0.07306039, -0.06939576],
#          [-0.0099466 , -0.02403509,  0.01342688, ...,  0.0286766 ,
#            0.01722112,  0.01542115],
#          [ 0.00958191,  0.03864382, -0.04308864, ..., -0.05022204,
#           -0.04068499, -0.06755127]], dtype=float32),
#   's_lay.1.bias': array([-0.01276367, -0.02701885,  0.01151103,  0.02461726, -0.0457635 ,
#           0.02050919,  0.01606315,  0.04188764,  0.02693565,  0.0878875 ,
#           0.08766912, -0.06636277,  0.00358548, -0.10062669,  0.02446824,
#          -0.03230815, -0.07658502, -0.10696585,  0.01374554, -0.05830921,
#           0.01635721,  0.0306452 , -0.05822597,  0.07516091,  0.00748084,
#          -0.08687317, -0.00808421, -0.05302566,  0.05279041, -0.09095245,
#           0.06427807,  0.07921998], dtype=float32),
#   's_lay.2.weight': array([[ 0.07813299,  0.05469928,  0.03926899, ..., -0.06256381,
#            0.08078702,  0.06310897],
#          [-0.03150436,  0.06530842, -0.06339779, ...,  0.03981594,
#           -0.07576303, -0.04367931],
#          [ 0.01948043,  0.06572679, -0.0583073 , ...,  0.04636365,
#            0.07001001,  0.00879547],
#          ...,
#          [-0.09103454, -0.01462079,  0.00922338, ...,  0.07003257,
#            0.06329085, -0.02596902],
#          [-0.03570409, -0.05790556,  0.07808331, ..., -0.07843445,
#           -0.02178563, -0.07629371],
#          [ 0.00256137, -0.06239634, -0.0812043 , ..., -0.0761965 ,
#            0.06253262, -0.06883376]], dtype=float32),
#   's_lay.2.bias': array([ 0.03875406,  0.09339678, -0.08777454, -0.04732209,  0.02629945,
#           0.05146495, -0.06841466,  0.04589371,  0.04936452,  0.01699912,
#          -0.03689365, -0.04799975, -0.00821731,  0.04113039,  0.0335169 ,
#           0.0194579 ,  0.01322123, -0.02111935,  0.02831956, -0.08858504,
#          -0.02092041,  0.06646197, -0.07555395,  0.03513855,  0.01401409,
#          -0.04708217, -0.05686023, -0.03033761,  0.00649012, -0.0356311 ,
#           0.0427934 ,  0.07188266], dtype=float32),
#   's_lay.3.weight': array([[-0.03766588,  0.06506803,  0.00767407, ...,  0.0764082 ,
#            0.08320557, -0.08359289],
#          [ 0.01851636,  0.00805397,  0.00705792, ...,  0.08784409,
#            0.0871359 ,  0.01232297],
#          [ 0.00683451,  0.03248983,  0.05644738, ..., -0.06580537,
#            0.05435728, -0.08253977],
#          ...,
#          [-0.08552022, -0.01368216,  0.06635733, ...,  0.04263501,
#           -0.01603903, -0.05259323],
#          [ 0.04925805,  0.09155224,  0.07963409, ..., -0.02378482,
# ...
#   'v_after.bias': array([ 0.06187014,  0.01716254,  0.01082121,  0.05574574,  0.00133931,
#          -0.05832455, -0.05378636, -0.02942986, -0.06185707, -0.01719922,
#           0.00769745,  0.04120824, -0.07908262, -0.06824858, -0.06135457,
#          -0.00287102,  0.01406143, -0.02154909,  0.01424707, -0.00682667,
#           0.03937774,  0.07456855, -0.04484352, -0.05589507, -0.08941568,
#           0.03062845, -0.01567888,  0.05976671, -0.02057881,  0.0923772 ,
#           0.08184901,  0.06130067], dtype=float32),
#   'w_spin_u.weight': array([[ 0.14157452, -0.05089541, -0.04670824, ...,  0.08944562,
#           -0.07066695, -0.05136338],
#          [-0.0618374 ,  0.13602409, -0.0695946 , ...,  0.00855009,
#            0.0984263 , -0.04955975],
#          [ 0.06195985, -0.07573061,  0.04384829, ...,  0.12847032,
#           -0.16953549,  0.08628517],
#          ...,
#          [-0.12857047,  0.04456184,  0.02598976, ...,  0.07101201,
#           -0.04159278,  0.06360055],
#          [ 0.03195528,  0.13546263, -0.16160356, ...,  0.07857991,
#            0.14066237, -0.05925772],
#          [ 0.07683106, -0.00126129,  0.09886799, ..., -0.16769375,
#           -0.07866078,  0.0787486 ]], dtype=float32),
#   'w_spin_u.bias': array([ 0.09038109, -0.15055996,  0.17273451, -0.049067  ,  0.04267005,
#          -0.07135322,  0.07442396, -0.00205586,  0.04703814,  0.05669618,
#           0.03124322,  0.07526888, -0.10913527, -0.01942695,  0.13079043,
#          -0.1776317 , -0.14742337,  0.00230578,  0.09454541,  0.00042858,
#          -0.03626008,  0.06955897, -0.09284143,  0.12934025, -0.09760839,
#           0.06132541,  0.11347339, -0.04184484, -0.09230496,  0.10258603,
#           0.04646453, -0.05415065, -0.05510078,  0.14429362,  0.09754427,
#           0.12431102], dtype=float32),
#   'w_spin_d.weight': array([[-0.08752591,  0.06607346, -0.02311592,  0.08759461, -0.07514274,
#           -0.08960702, -0.1750243 , -0.1201003 , -0.07396851, -0.10719445,
#           -0.06146793, -0.02019629,  0.14986916, -0.00243341,  0.11190246,
#           -0.07036024, -0.02294827, -0.05312597, -0.07594359, -0.0531028 ,
#           -0.16328138,  0.12635931,  0.10972597, -0.15464579,  0.00513799,
#            0.02034463, -0.15498689, -0.03690492,  0.10311886, -0.08692552,
#            0.02707263,  0.02409082],
#          [ 0.03002076, -0.09713031, -0.01543639, -0.05138665,  0.13902436,
#            0.1797804 ,  0.02731783,  0.18107383,  0.10070128,  0.18552718,
#            0.10827394,  0.15111907,  0.06327341,  0.01162156,  0.06362984,
#           -0.15824871,  0.10764006, -0.05802629,  0.05539778, -0.19621453,
#           -0.08364511, -0.03924708, -0.0443281 , -0.1805241 ,  0.06421811,
#           -0.06691481,  0.13734774, -0.13880835, -0.01070079,  0.12267016,
#           -0.14197838, -0.12255147],
#          [ 0.11973286, -0.06686169, -0.08615394, -0.01051253,  0.06032567,
#            0.05646528,  0.04694743, -0.09000716, -0.12877645,  0.17016703,
#            0.13191329,  0.13789706, -0.09981356,  0.17946783, -0.10019264,
#            0.01778506,  0.11812081, -0.02998075, -0.09378746, -0.14712006,
#           -0.17232585,  0.05114092,  0.14736034, -0.06323682,  0.14509206,
#            0.11144385, -0.13379028],
#          [ 0.02133213,  0.11953993,  0.01259991, -0.0102604 , -0.04408153,
#           -0.10276866,  0.11311217,  0.12697758,  0.00092908,  0.00727079,
#            0.05751329, -0.17032081,  0.06801854, -0.13850184,  0.05467501,
#            0.17996803,  0.02464277,  0.10162171, -0.1465183 ,  0.16594246,
#            0.0382548 ,  0.0724897 ,  0.07498042, -0.06236899, -0.10224103,
#           -0.11734644,  0.1491308 ,  0.03697267,  0.1413042 , -0.13691008,
#            0.12353969, -0.04993195],
#          [ 0.0317608 , -0.03638175, -0.1334539 ,  0.09473047, -0.16173008,
#           -0.0460665 ,  0.01746956,  0.10940479, -0.1157263 , -0.02405488,
#            0.14629385,  0.0546172 ,  0.18004686, -0.06090083,  0.13135129,
#           -0.15528822,  0.02591947, -0.10433017, -0.02460727, -0.15530664,
#           -0.12846239, -0.0532525 ,  0.12321429, -0.09797823,  0.00845401,
#            0.08986582,  0.05027113,  0.0863099 ,  0.02035058,  0.03283736,
#           -0.05122379, -0.05028301],
#          [-0.0426714 ,  0.04425174,  0.06948551, -0.06188801, -0.08335408,
#            0.13242134, -0.17184764, -0.11203282, -0.13112494, -0.17193832,
#           -0.05445031, -0.14631079,  0.05610321, -0.04905306,  0.07215568,
#           -0.01205273, -0.09375909, -0.17328504,  0.16333859, -0.01982483,
#            0.06134958,  0.07220233, -0.12632477, -0.10623371, -0.08657408,
#           -0.04856177, -0.13648367, -0.05153102, -0.10604497, -0.06928526,
#            0.00485364,  0.10231584],
#          [ 0.07319483,  0.11764434,  0.07970146, -0.08054503,  0.13586138,
#            0.05643611,  0.14660986,  0.05910273, -0.15666091, -0.1594123 ,
#            0.13489236,  0.09512201, -0.04916175,  0.17572252, -0.01314808,
#           -0.00980245, -0.05696772,  0.08185688,  0.05668141,  0.14810684,
#            0.07769428,  0.10786297,  0.0253121 , -0.13584532, -0.06532905,
#           -0.08793896, -0.07957277, -0.14263654, -0.12830827, -0.11559808,
#            0.09830916,  0.08848646],
#          [ 0.13794097,  0.16860823,  0.07761036,  0.00239403, -0.15047017,
#           -0.13898304, -0.1431858 , -0.16027157, -0.14056544, -0.10733747,
#            0.13005479, -0.08664781,  0.0480746 , -0.03557534,  0.14490198,
#            0.0971125 ,  0.06608681, -0.08472444,  0.17490174,  0.15896957,
#            0.09485   ,  0.11511097, -0.05443697,  0.1392315 ,  0.05986684,
#           -0.07381016, -0.12803976,  0.05898324, -0.14792205, -0.1316752 ,
#           -0.07660658, -0.16419485],
#          [-0.02003247, -0.16172926,  0.16172005, -0.11016522,  0.18068962,
#            0.04047971, -0.05570795,  0.14168835,  0.05876149,  0.14427745,
#           -0.04991832, -0.0882774 , -0.01964852,  0.0673046 , -0.15615153,
#            0.13985261,  0.10521062, -0.06801158,  0.15205942,  0.03888092,
#           -0.10505579,  0.03913287, -0.1043326 ,  0.10107853, -0.05527598,
#           -0.00357253,  0.01530066,  0.11332924,  0.03899757,  0.0886145 ,
#           -0.11536325,  0.16115375],
#            0.10163647,  0.0222564 , -0.04779285, -0.11599159, -0.11083382,
#            0.15456553,  0.17570189,  0.10524506,  0.05341638, -0.06376617,
#            0.04249592,  0.1143705 ,  0.08754262, -0.14330885, -0.10988141,
#            0.16751692,  0.12712449, -0.07629095,  0.12007374, -0.02780964,
#           -0.06696779,  0.02695245,  0.04148994, -0.11227996, -0.09200566,
#            0.04148291,  0.14961916],
#          [ 0.07056822, -0.13868853, -0.06041113, -0.14569448, -0.08198284,
#           -0.15234694,  0.12589529,  0.07329915, -0.170323  ,  0.06806457,
#            0.04446573,  0.1242428 , -0.12129968,  0.0559195 , -0.00767269,
#            0.16748974, -0.06764632,  0.05022883, -0.1591079 , -0.09381516,
#            0.04332269, -0.14071926,  0.15180853,  0.05041439,  0.08615493,
#           -0.1080038 , -0.03344097,  0.17217435, -0.09282251,  0.1334307 ,
#            0.01761707,  0.0134786 ],
#          [ 0.11942367, -0.17294224, -0.10276722,  0.01334937,  0.07645591,
#            0.17370045, -0.10646184, -0.10826416, -0.15433882,  0.16537526,
#            0.01188111,  0.05397324, -0.1511005 , -0.1612111 , -0.13809499,
#            0.1162985 , -0.06193624,  0.10322687, -0.09855638,  0.07328837,
#           -0.03329001,  0.06401746, -0.04006725, -0.00464499, -0.09480413,
#           -0.13589652,  0.06932138, -0.18370539, -0.14585401,  0.11610081,
#            0.13298717,  0.13382407],
#          [-0.00748962, -0.10943361, -0.10455631, -0.1664624 , -0.05962962,
#            0.06154872, -0.11514517,  0.10567746, -0.14767033,  0.11386329,
#            0.13779712, -0.05992211,  0.01939604, -0.13087888,  0.09307078,
#           -0.10078216, -0.14610812, -0.12382508,  0.02980954, -0.03091367,
#            0.03150694,  0.11556582,  0.04674625,  0.11499605,  0.11670447,
#            0.1294725 ,  0.12766574,  0.13505292,  0.02335057, -0.17706397,
#           -0.13100931,  0.04802788],
#          [ 0.14333823,  0.14385772,  0.02890332,  0.13916099,  0.10105245,
#           -0.04968135, -0.05029735, -0.14447574,  0.11338254,  0.00789248,
#           -0.17677474,  0.00552258,  0.17758858, -0.1745562 , -0.01739298,
#            0.01347647, -0.1195285 ,  0.08532245,  0.14756048, -0.07558506,
#            0.1820243 ,  0.13284898,  0.14738196,  0.09434157, -0.11538909,
#            0.13110736, -0.04952014,  0.16024418, -0.10750802, -0.13758665,
#            0.09489308,  0.09353957],
#          [ 0.12863721,  0.02098592, -0.12871143,  0.11932385,  0.08992486,
#            0.08576567,  0.13724302,  0.0983268 , -0.0868893 , -0.1373757 ,
#           -0.13802165,  0.1425079 , -0.08717408, -0.05995382, -0.06121632,
#           -0.02630377, -0.10458992,  0.14855608, -0.04855558, -0.10088069,
#           -0.08666916, -0.02579353, -0.14248663, -0.03443984,  0.13222547,
#           -0.00913566, -0.05777423,  0.06005485,  0.1769623 ,  0.12291931,
#            0.04907235, -0.1354648 ],
#          [ 0.10178952,  0.06621448, -0.0542634 ,  0.00829966, -0.0398677 ,
#           -0.02458543,  0.14328189, -0.05701379,  0.00865478, -0.08031065,
#            0.10349271, -0.06541411, -0.12613489, -0.03576948,  0.08417208,
#            0.15638418, -0.07298281,  0.07363824,  0.08089273, -0.06348042,
#           -0.12152055,  0.11500835, -0.1453359 , -0.10257595, -0.06399881,
#            0.01513999,  0.0443014 , -0.03969544, -0.09405882,  0.06631581,
#            0.15770695, -0.05089063]], dtype=float32),
#   'w_spin_d.bias': array([-0.0849826 , -0.00043714, -0.12278018, -0.12169246, -0.12393346,
#          -0.01335618,  0.05786594, -0.16744545, -0.01700665, -0.16269845,
#          -0.05740671, -0.01458815, -0.09416784,  0.00652789, -0.07057261,
#           0.09961504, -0.13652866,  0.10039756,  0.0125553 ,  0.03958924,
#          -0.06848117, -0.19309902,  0.1411411 ,  0.16955145, -0.03590649,
#          -0.00619981,  0.06733035, -0.14151967], dtype=float32),
#   'w_final.weight': array([[0.24143013, 0.2602416 , 0.24737492, 0.24498112]], dtype=float32)}}

# %%
y = d_flatten_r(x)

print(v_d.keys())

print(y.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y = d_flatten_r(x)
#       3 print(v_d.keys())
#       5 print(y.keys())
#
# NameError: name 'd_flatten_r' is not defined

# %% [markdown]
# # fin
#
# ## TODO
# - [x] demo wandb
# - [ ] test slurm
# - [ ] test Accelerate
# - [ ] distribution (Accelerate + slurm)
# - [ ] docker
# - [ ] kubernetes
# - [ ] deploy as pip install package
# - [ ] lightning integration

# %%
c.mode in (RUNMODE.train, RUNMODE.pre)
# Out:
# True

# %%
# 


import torch as th
from torch.utils.data import DataLoader, Dataset, random_split
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import WandbLogger
import pytorch_lightning as pl

from accelerate import Accelerator

import wandb

from nn_nananana_ansatz.hwat import Ansatz as Model, Scf

pl.seed_everything(c.seed)

accelerator = Accelerator(
    device_placement = True,  # Automatically places tensors on the proper device
    fp16 = True,  # Enables automatic mixed precision training (AMP)
    cpu=True,  # Forces the use of CPU even when GPUs are available
    split_batches=True,  # Splits the batches on the CPU before sending them to the device
    num_processes=1,  # Number of processes to use for distributed training (1 means no distributed training)
    local_rank=0,  # Local rank of the process (for distributed training)
)


model = Model(c.modelcfg)

wandb_logger = WandbLogger(
    project		= c.paths.project,
    log_model	= c.logger.log_model
)

wandb_logger.watch(model)

checkpoint_callback = ModelCheckpoint(
    dirpath				= c.model_save_path,
    filename			= "model-{epoch:02d}-{val_loss:.2f}",
    save_top_k			= 1,
    monitor				= "val_loss",
    mode				= "min",
    save_weights_only	= True,
    save_last			= True,
    period				= c.checkpoint_frequency,
    verbose				= True,
)

trainer = pl.Trainer(
    max_epochs	= c.n_epoch,
    accelerator	= accelerator,
    logger		= wandb_logger,
    callbacks	= [checkpoint_callback],
    gpus		= th.cuda.device_count(),
)

trainer.fit(model, train_loader, val_loader)

wandb.finish()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [16], line 6
#       4 import torch as th
#       5 from torch.utils.data import DataLoader, Dataset, random_split
# ----> 6 from pytorch_lightning.callbacks import ModelCheckpoint
#       7 from pytorch_lightning.loggers import WandbLogger
#       8 import pytorch_lightning as pl
#
# ModuleNotFoundError: No module named 'pytorch_lightning'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c3092bd2-44d7-455e-aedb-c6812270d279' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
