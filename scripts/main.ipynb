# %%
# %load_ext autoreload
# %autoreload 2

# %%
from env import env # environment variables
from pathlib import Path
from nn_nananana_ansatz.pyfig.pretty import print_tree
print_tree('../', ignore=['-dep-v2', '-dep', 'build', 'wandb', 'tmp*'])
# Out:
# env_file: /home/m/code/nn-nananana-ansatz/scripts/.env
# Env(
#     test='xyz',
#     WANDB_USER='xmkqv',
#     WANDB_PROJECT='mc-hierachii',
#     WANDB_ENTITY='xmax1',
#     GITHUB_USER='xmkqv',
#     GITHUB_REPO='mc-hierachii',
#     GITHUB_TOKEN=SecretStr('**********')
# )
# environ test: True
# logger handler: 1
# logger level: INFO
# change level: os.environ["LOG: or "log"] = "LEVEL" or "level"
# levels: TRACE, DEBUG, INFO, SUCCESS, WARNING, ERROR, CRITICAL
# Ignoring:
# ['-dep-v2', '-dep', 'build', 'wandb', 'tmp*']
# ╭────── Directory Tree ──────╮
# │ 📂 ]8;id=619253;file://../\../]8;;\                     │
# │ ├── 📂 ]8;id=912599;file://../nn_nananana_ansatz\nn_nananana_ansatz]8;;\  │
# │ │   ├── 📂 ]8;id=185747;file://../nn_nananana_ansatz/pyfig\pyfig]8;;\           │
# │ │   │   ├── 📄 ]8;id=919399;file://../nn_nananana_ansatz/pyfig/-colors.css\-colors]8;;\]8;id=867191;file://../nn_nananana_ansatz/pyfig/-colors.css\.css]8;;\ │
# │ │   │   ├── 🐍 ]8;id=928794;file://../nn_nananana_ansatz/pyfig/bug.py\bug]8;;\]8;id=8830;file://../nn_nananana_ansatz/pyfig/bug.py\.py]8;;\      │
# │ │   │   ├── 🐍 ]8;id=397119;file://../nn_nananana_ansatz/pyfig/env_dist.py\env_dist]8;;\]8;id=367157;file://../nn_nananana_ansatz/pyfig/env_dist.py\.py]8;;\ │
# │ │   │   ├── 🐍 ]8;id=961036;file://../nn_nananana_ansatz/pyfig/files.py\files]8;;\]8;id=305303;file://../nn_nananana_ansatz/pyfig/files.py\.py]8;;\    │
# │ │   │   ├── 🐍 ]8;id=440618;file://../nn_nananana_ansatz/pyfig/log.py\log]8;;\]8;id=801080;file://../nn_nananana_ansatz/pyfig/log.py\.py]8;;\      │
# │ │   │   ├── 🐍 ]8;id=414135;file://../nn_nananana_ansatz/pyfig/paths.py\paths]8;;\]8;id=636747;file://../nn_nananana_ansatz/pyfig/paths.py\.py]8;;\    │
# │ │   │   ├── 🐍 ]8;id=167871;file://../nn_nananana_ansatz/pyfig/plugins.py\plugins]8;;\]8;id=894865;file://../nn_nananana_ansatz/pyfig/plugins.py\.py]8;;\  │
# │ │   │   ├── 🐍 ]8;id=90128;file://../nn_nananana_ansatz/pyfig/pretty.py\pretty]8;;\]8;id=3130;file://../nn_nananana_ansatz/pyfig/pretty.py\.py]8;;\   │
# │ │   │   ├── 🐍 ]8;id=927809;file://../nn_nananana_ansatz/pyfig/pydanmod.py\pydanmod]8;;\]8;id=804960;file://../nn_nananana_ansatz/pyfig/pydanmod.py\.py]8;;\ │
# │ │   │   ├── 🐍 ]8;id=845062;file://../nn_nananana_ansatz/pyfig/pyfig.py\pyfig]8;;\]8;id=117132;file://../nn_nananana_ansatz/pyfig/pyfig.py\.py]8;;\    │
# │ │   │   ├── 🐍 ]8;id=499804;file://../nn_nananana_ansatz/pyfig/schema.py\schema]8;;\]8;id=524835;file://../nn_nananana_ansatz/pyfig/schema.py\.py]8;;\   │
# │ │   │   ├── 🐍 ]8;id=319069;file://../nn_nananana_ansatz/pyfig/typfig.py\typfig]8;;\]8;id=88083;file://../nn_nananana_ansatz/pyfig/typfig.py\.py]8;;\   │
# │ │   │   └── 🐍 ]8;id=586030;file://../nn_nananana_ansatz/pyfig/utils.py\utils]8;;\]8;id=562344;file://../nn_nananana_ansatz/pyfig/utils.py\.py]8;;\    │
# │ │   ├── 🐍 ]8;id=229531;file://../nn_nananana_ansatz/appfig.py\appfig]8;;\]8;id=992588;file://../nn_nananana_ansatz/appfig.py\.py]8;;\       │
# │ │   ├── 🐍 ]8;id=548093;file://../nn_nananana_ansatz/cli.py\cli]8;;\]8;id=313869;file://../nn_nananana_ansatz/cli.py\.py]8;;\          │
# │ │   ├── 🐍 ]8;id=880299;file://../nn_nananana_ansatz/hwat.py\hwat]8;;\]8;id=257509;file://../nn_nananana_ansatz/hwat.py\.py]8;;\         │
# │ │   ├── 🐍 ]8;id=795065;file://../nn_nananana_ansatz/model.py\model]8;;\]8;id=216633;file://../nn_nananana_ansatz/model.py\.py]8;;\        │
# │ │   ├── 🐍 ]8;id=621523;file://../nn_nananana_ansatz/systems.py\systems]8;;\]8;id=623089;file://../nn_nananana_ansatz/systems.py\.py]8;;\      │
# │ │   ├── 🐍 ]8;id=543418;file://../nn_nananana_ansatz/torch_utils.py\torch_utils]8;;\]8;id=75537;file://../nn_nananana_ansatz/torch_utils.py\.py]8;;\  │
# │ │   ├── 🐍 ]8;id=827117;file://../nn_nananana_ansatz/typer-cli.py\typer-cli]8;;\]8;id=432961;file://../nn_nananana_ansatz/typer-cli.py\.py]8;;\    │
# │ │   └── 🐍 ]8;id=14099;file://../nn_nananana_ansatz/utils.py\utils]8;;\]8;id=335328;file://../nn_nananana_ansatz/utils.py\.py]8;;\        │
# │ ├── 📂 ]8;id=776847;file://../scripts\scripts]8;;\             │
# │ │   ├── 📂 ]8;id=625007;file://../scripts/data\data]8;;\            │
# │ │   ├── 🐍 ]8;id=668799;file://../scripts/appfig.py\appfig]8;;\]8;id=420946;file://../scripts/appfig.py\.py]8;;\       │
# │ │   ├── 🐍 ]8;id=563432;file://../scripts/env.py\env]8;;\]8;id=448078;file://../scripts/env.py\.py]8;;\          │
# │ │   ├── 🐍 ]8;id=2962;file://../scripts/lightning.py\lightning]8;;\]8;id=464593;file://../scripts/lightning.py\.py]8;;\    │
# │ │   ├── 📄 ]8;id=362168;file://../scripts/main.ipynb\main]8;;\]8;id=473024;file://../scripts/main.ipynb\.ipynb]8;;\      │
# │ │   ├── 📄 ]8;id=207896;file://../scripts/tmp15axw1qv\tmp15axw1qv]8;;\     │
# │ │   ├── 📄 ]8;id=301366;file://../scripts/tmp4gc1tcbv\tmp4gc1tcbv]8;;\     │
# │ │   ├── 📄 ]8;id=664012;file://../scripts/tmp6winnna5\tmp6winnna5]8;;\     │
# │ │   ├── 📄 ]8;id=96406;file://../scripts/tmpdafdq_bg\tmpdafdq_bg]8;;\     │
# │ │   ├── 📄 ]8;id=193944;file://../scripts/tmpmsb7yqta\tmpmsb7yqta]8;;\     │
# │ │   ├── 📄 ]8;id=53207;file://../scripts/tmpp_o0velt\tmpp_o0velt]8;;\     │
# │ │   ├── 📄 ]8;id=166588;file://../scripts/tmppa_81sub\tmppa_81sub]8;;\     │
# │ │   ├── 📄 ]8;id=687192;file://../scripts/tmpqyur3bzn\tmpqyur3bzn]8;;\     │
# │ │   └── 📄 ]8;id=723879;file://../scripts/tmpwelvs1ku\tmpwelvs1ku]8;;\     │
# │ ├── 📄 ]8;id=338137;file://../pdm.lock\pdm]8;;\]8;id=682211;file://../pdm.lock\.lock]8;;\            │
# │ ├── 📄 ]8;id=975009;file://../pyproject.toml\pyproject]8;;\]8;id=817767;file://../pyproject.toml\.toml]8;;\      │
# │ └── 📄 ]8;id=801186;file://../README.md\README]8;;\]8;id=922779;file://../README.md\.md]8;;\           │
# ╰────────────────────────────╯

# %% [markdown]
# Geometries of molecular oxygen in different spin states and oxidation states

# %% [markdown]
# O2, mult3	1.2075
# O2, mult1	1.2255
# O2+, mult2	1.1164

# %%
from rich.pretty import pprint
from rich import print

from nn_nananana_ansatz.pyfig.pyfig import DEVICES, DTYPES, RUNMODE
from nn_nananana_ansatz.pyfig.paths import Paths
from nn_nananana_ansatz.pyfig.plugins import Logger, Opt, OPTS, LOGMODE, RUNTYPE
from nn_nananana_ansatz.pyfig.utils import get_attrs

from nn_nananana_ansatz.systems import System
from appfig import Ansatzcfg, Walkers, Pyfig

# %%
class Pyfig(Pyfig):

	seed: int           	= 42
	debug: bool         	= False

	device: DEVICES     	= DEVICES.gpu
	dtype: DTYPES          	= DTYPES.float32
	
	paths: Paths = Paths(
		project         = 'hwat',
		exp_name        = 'test',
		run_name        = 'run.py',
		exp_data_dir    = 'data',
	)

	mode: RUNMODE       	= RUNMODE.train  # adam, sgd

	n_epoch: int      		= 100
	n_step: int      		= 100

	loss: str        		= 'vmc'  # orb_mse, vmc

	logger: Logger      = Logger(
		exp_name 		= paths.exp_name, 
		entity			= env.WANDB_ENTITY,
		project			= paths.project,
		n_log_metric	= 2,
		n_log_state		= -1,
		run_path		= paths.run_path,
        runtype         = RUNTYPE.runs,
		exp_data_dir	= paths.exp_data_dir,
	)

	opt: Opt         	= Opt(
		name = OPTS.AdamW,
	)

	walkers: Walkers = Walkers(
		n_b = 64,
        n_equil_step= 10 # DEBUGGING
	)

	system: System = System( # validation issue when nested, don't nest
	a =    [[0.0, 0.0, 0.0], [1.2075, 0.0, 0.0]],
	a_z =  [8, 8],
	charge = 0,
	spin = 2, # total spin, unparse
	)
	
	ansatzcfg: Ansatzcfg = Ansatzcfg(
		n_l 	= 3,
		ke_method 	= 'grad_grad', # inefficient, can do jit compiled version
	)

c = Pyfig( # edit here also

	seed= 1,
	
	ansatzcfg= Ansatzcfg(
		n_l 	= 2,
		ke_method 	= 'grad_grad',
	),
)

from nn_nananana_ansatz.pyfig.utils import print_maybe_inspect

for k,v in c.items():
	print(k, v)
# attrs = get_attrs(c)
# pprint(attrs)

# attrs = get_attrs(c.walkers)
# pprint(attrs)
# Out:
# ansatzcfg
# Ansatzcfg(
#     n_l=2,
#     n_sv=32,
#     n_pv=16,
#     n_fb=3,
#     n_det=4,
#     n_final_out=1,
#     terms_s_emb=['ra', 'ra_len'],
#     terms_p_emb=['rr', 'rr_len'],
#     ke_method='grad_grad'
# )
# debug False
# device cuda
# dtype float32
# logger
# Logger(
#     entity='xmax1',
#     project='hwat',
#     exp_name='test',
#     run_path=PosixPath('projects/hwat/run.py'),
#     exp_data_dir=PosixPath('exp/exp_data'),
#     log_interval=10,
#     save_interval=100,
#     resume_checkpoint='',
#     n_log_metric=2,
#     n_log_state=-1,
#     log_mode=<LOGMODE.online: 'online'>,
#     log_model=True,
#     runtype=<RUNTYPE.runs: 'runs'>,
#     job_type='dev'
# )
# loss vmc
# mode train
# n_epoch 100
# n_step 100
# opt
# Opt(
#     name=<OPTS.AdamW: 'AdamW'>,
#     lr=0.001,
#     init_lr=0.001,
#     betas=[0.9, 0.999],
#     beta=0.9,
#     warm_up=100,
#     eps=0.0001,
#     weight_decay=0.0,
#     hessian_power=1.0,
#     lr_anneal_steps=1000,
#     ema_rate='0.9999'
# )
# paths
# Paths(
#     project='hwat',
#     exp_name='test',
#     run_name=PosixPath('run.py'),
#     env_file=PosixPath('/home/m/code/nn-nananana-ansatz/nn_nananana_ansatz/pyfig/.env'),
#     lo_ve_path='',
#     exp_id='ffbb2b09b7',
#     home=PosixPath('.'),
#     exp_dir=PosixPath('exp')
# )
# seed 1
# system
# System(
#     a=ndarray([[0.    , 0.    , 0.    ],
#          [0.    , 1.2075, 0.    ]]),
#     a_z=ndarray([8, 8]),
#     charge=0,
#     spin=2
# )
# walkers
# Walkers(n_b=64, n_corr=20, n_equil_step=10, acc_target=0.5, init_data_scale=0.1)

# %%
# leave for now
# from pyfig.cli import TyperSource
# ts = TyperSource(c)
# ts.write()
# print(ts)

# %%
# import pandas as pd
# data_explore = ex.reshape(ex.shape[:3], -1) / 255.
# df = pd.DataFrame.from_dict({f"dim_{i}": data_explore[:100, i] for i in range(100)})
# df.head()
# import pygwalker as pyg
# gwalker = pyg.walk(df)

# %%
from nn_nananana_ansatz.hwat import Scf # https://github.com/pyscf wrapper

scf = Scf(system= c.system)
scf.init_app()
print(scf)

# electronic spin
# define the diffence between spin total, lots [:
# <S^2> = 4.4408921e-16  2S+1 = 1
# Out:
# pyfig:pyscf:
# converged SCF energy = -144.084750676126  <S^2> = 2.0008124  2S+1 = 3.0005416
# app:init_app: mo_coef shape: (2, 10, 10)
# **** MO energy ****
#                              alpha | beta                alpha | beta
# MO #1   energy= -21.0284314415787  | -20.9911041542446  occ= 1 | 1
# MO #2   energy= -20.9471190199291  | -20.9065291461555  occ= 1 | 1
# MO #3   energy= -2.40494141278155  | -2.3222595169621   occ= 1 | 1
# MO #4   energy= -1.32132963072916  | -1.11969361990839  occ= 1 | 1
# MO #5   energy= -1.32132963072916  | -1.11969361990839  occ= 1 | 1
# MO #6   energy= -0.987304712466787 | -0.788701048233836 occ= 1 | 1
# MO #7   energy= -0.85914411033142  | -0.757484628916062 occ= 1 | 1
# MO #8   energy= -0.115754124642637 | 0.680443753354031  occ= 1 | 0
# MO #9   energy= -0.115754124642635 | 0.680443753354034  occ= 1 | 0
# MO #10  energy= 3.24064806202365   | 3.35909272248913   occ= 0 | 0
#
# To work with the spin densities directly, `use mulliken_meta_spin()` only printing them here.
#
#  ** Mulliken spin pop alpha/beta on meta-lowdin orthogonal AOs **
#  ** Mulliken Spin Density (per atom)  **
# spin density of  0 O =      1.00000
# spin density of  1 O =      1.00000
#  ** Mulliken pop alpha/beta on meta-lowdin orthogonal AOs **
#  ** Mulliken atomic charges   ( Nelec_alpha | Nelec_beta ) **
# charge of  0O =      0.00000  (     4.50000      3.50000 )
# charge of  1O =      0.00000  (     4.50000      3.50000 )
# Dipole moment(X, Y, Z, Debye):  0.00000, -0.00000,  0.00000
# UHF object of <class 'pyscf.scf.uhf.UHF'>
# <nn_nananana_ansatz.hwat.Scf object at 0x7f955210f970>

# %%
from copy import deepcopy

import torch
from torch.utils.data import DataLoader
from functorch import make_functional_with_buffers, vmap

from nn_nananana_ansatz.hwat import PyfigDataset, Ansatz



# CONVERT TO TORCH
dtype = dict(float32= torch.float32, float64= torch.float64, float16= torch.float16).get(c.dtype)
device = torch.device(c.device)
system_th = get_attrs(c.system)
system_th.update(dict(
    a= torch.tensor(system_th['a'], dtype= dtype, device= device), 
    a_z= torch.tensor(system_th['a_z'], dtype= dtype, device= device)
))
mo_coef = torch.tensor(scf.mo_coef, device=device, dtype=dtype)


print(f"""
device: {device}
dtype: {dtype}
""")
# INITIALISE THE MODEL
model = Ansatz(**system_th, **get_attrs(c.ansatzcfg), mol= None, mo_coef= mo_coef).to(device=device, dtype= dtype)
model_to_fn: torch.nn.Module = deepcopy(model)
model_fn, param, buffer = make_functional_with_buffers(model_to_fn)
model_fn_vmap = vmap(model_fn, in_dims=(None, None, 0))
del model
model = Ansatz(**system_th, **get_attrs(c.ansatzcfg), mol= scf.mol, mo_coef= mo_coef).to(device=device, dtype= dtype)

# INITIALISE THE DATASET
dataset = PyfigDataset(c, system= c.system, walkers= c.walkers)
def custom_collate(batch):
	return batch[0]
dataloader = DataLoader(dataset, batch_size= 1, collate_fn= custom_collate)  # c.data.n_b otherwise because of the internal sampler

# INITIALISE THE OPTIMISER
from torch.optim import Optimizer
from nn_nananana_ansatz.utils import get_opt
opt: Optimizer = get_opt(**get_attrs(c.opt))(model.parameters())

# TORCH SETTINGS https://jamesmccaffrey.wordpress.com/2019/01/23/pytorch-train-vs-eval-mode/
# not important 
model.train()
if 'eval' in c.mode:
    model.eval()

# wrap up
dataloader.dataset.init_dataset(c, device= device, dtype= dtype, model= model)
# Out:
# device: cuda
# dtype: torch.float32
# model fb layers:
#  [(32, 32), (128, 32), (128, 32), (128, 32)] [(4, 16), (16, 16), (16, 16), (16, 16)]
# model fb layers:
#  [(32, 32), (128, 32), (128, 32), (128, 32)] [(4, 16), (16, 16), (16, 16), (16, 16)]
# hwat:dataset: init
# hwat:dataset:init: center_points
# tensor([[0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 1.2075, 0.0000]], dtype=torch.float64)
# dataset:len  100
# dataset:init_dataset: data  torch.Size([64, 16, 3]) torch.float32 cuda:0
# /home/m/code/nn-nananana-ansatz/.venv/lib/python3.10/site-packages/torch/_functorch/deprecated.py:101: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.make_functional_with_buffers is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.func.functional_call instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('make_functional_with_buffers', 'torch.func.functional_call')
# /home/m/code/nn-nananana-ansatz/.venv/lib/python3.10/site-packages/torch/_functorch/deprecated.py:58: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# |    |     deltar |        acc |      diff |
# |---:|-----------:|-----------:|----------:|
# |  0 | 0.001      | 0.676406   | 0.0363906 |
# |  1 | 0.00215443 | 0.674024   | 0.0367422 |
# |  2 | 0.00464159 | 0.624766   | 0.0527188 |
# |  3 | 0.01       | 0.66668    | 0.0251953 |
# |  4 | 0.0215444  | 0.643125   | 0.0675    |
# |  5 | 0.0464159  | 0.565859   | 0.0941406 |
# |  6 | 0.1        | 0.48168    | 0.17832   |
# |  7 | 0.215443   | 0.246133   | 0.413867  |
# |  8 | 0.464159   | 0.0463281  | 0.613672  |
# |  9 | 1          | 0.00628906 | 0.653711  |
# dataset:init_dataset deltar  tensor([0.0100], device='cuda:0')
# equil  0  acc  0.6519531011581421  deltar  -0.010118304751813412
# dataset:init_dataset sampler is pretraining  False
# dataset:init_dataset
# data torch.Size([64, 16, 3]) cuda:0 torch.float32 tensor(0.2070, device='cuda:0') tensor(0.7467, device='cuda:0')
# acc torch.Size([1]) cuda:0 torch.float32 tensor(0.6551, device='cuda:0') tensor(nan, device='cuda:0')
# deltar torch.Size([1]) cuda:0 torch.float32 tensor(0.0520, device='cuda:0') tensor(nan, device='cuda:0')
# p_start torch.Size([64]) cuda:0 torch.float32 tensor(0., device='cuda:0') tensor(0., device='cuda:0')

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME']='main'
import wandb
from nn_nananana_ansatz.pyfig.utils import gen_rnd

wandb.init( # https://wandb.ai/
	project = env.WANDB_PROJECT,
	entity= env.WANDB_ENTITY,
	name= gen_rnd(), # c.logger.exp_name,
	mode= c.logger.log_mode,
	tags= [c.logger.runtype, c.mode],
)
# Out:
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/home/m/code/nn-nananana-ansatz/scripts/wandb/run-20230601_225958-rovg1cve</code>
# Syncing run <strong><a href='https://wandb.ai/xmax1/mc-hierachii/runs/rovg1cve' target="_blank">c110b589e8</a></strong> to <a href='https://wandb.ai/xmax1/mc-hierachii' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xmax1/mc-hierachii' target="_blank">https://wandb.ai/xmax1/mc-hierachii</a>
#  View run at <a href='https://wandb.ai/xmax1/mc-hierachii/runs/rovg1cve' target="_blank">https://wandb.ai/xmax1/mc-hierachii/runs/rovg1cve</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/xmax1/mc-hierachii/runs/rovg1cve?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from nn_nananana_ansatz.hwat import loss_fn, loss_fn_pretrain, update_grads, update_params
from nn_nananana_ansatz.pyfig.utils import compute_metrix
from nn_nananana_ansatz.torch_utils import npify_tree

log_params = False
mode = c.mode = 'train'
model.requires_grad_(True) # torch stuff: sets parameters to compute gradients in backward pass

print(f"""
mode: {mode}
device: {device}
dtype: {dtype}
n_step {c.n_step}
n_log_metric: {c.logger.n_log_metric}
wandb: {wandb.run.name}
""")

v_cpu_d = dict()
for step, loader_d in enumerate(dataloader, start= 1):  # dataloader contains sampling loop

	data = loader_d['data'].to(device= device, dtype= dtype)  # move the data to the gpu
	model.zero_grad(set_to_none= True) # torch stuff: zero the gradient attached to the parameters of the model

	if c.mode == 'train': # compute the loss for different modes
		v_d = loss_fn(model, data, model_fn, system_th, c.ansatzcfg)  # general. v_d contains everything
	elif c.mode == 'pre':
		v_d = loss_fn_pretrain(model, data, c, step)
	loss = v_d.get('loss', torch.tensor(0.0, device= device, dtype= dtype)) # administrative

	create_graph = c.opt.name.lower() == 'AdaHessian'.lower() # torch stuff for autograd & second order optimisers
	loss.backward(create_graph= create_graph) # autograd: do backpropagation
	v_d['grads'] = {k: p.grad.detach() for k,p in model.named_parameters()}
	update_grads(model, v_d, step) # update the gradients on the model parameters
	
	update_params(model, opt)
	v_d['params'] = {k:p.detach() for k,p in model.named_parameters()} # collecting for logging

	if step % c.logger.n_log_metric == 0:
		
		if not log_params:
			v_d.pop('params')
			v_d.pop('grads')

		v_cpu_d: dict = npify_tree(v_d) # convert to numpy
		v_metrix: dict = compute_metrix(v_cpu_d) # rewrite the names and compute the metrics
		
		wandb.log(v_metrix) # send to wandb
# Out:
# mode: train
# device: cuda
# dtype: torch.float32
# n_step 100
# n_log_metric: 2
# wandb: c110b589e8

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>energy/e.mean</td><td>▆▆▆▄▅▆▇▇█▇▇▅▄▃▃▃▄▄▄▅▄▄▃▃▂▂▂▃▃▄▄▂▃▂▂▂▃▁▃▁</td></tr><tr><td>energy/e.std</td><td>▆▄▃▃▄▅▃▂▂▃▂▄▂▂▂▂▂▂▂▃▂▂▂▃▃▂▃▃█▁▁▇▃▅▂▁▃▄▁▂</td></tr><tr><td>energy/ke.mean</td><td>▂▂▃▄▅▄▂▁▁▁▁▂▃▄▅▅▅▄▄▃▄▄▄▄▄▅▇▇▅▄▄▆▅▇▆▇▇█▆▇</td></tr><tr><td>energy/ke.std</td><td>▂▂▂▂▃▃▁▁▁▁▁▂▂▃▃▃▃▂▂▂▃▃▃▃▃▄�