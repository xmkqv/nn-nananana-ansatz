# %%
import panel as pn
pn.extension()
from pydantic import BaseModel

class Pyfig(BaseModel):
	opt: list = ['Adam', 'SGD']
	float_array: list = []  # str to List[float]
	test: bool = True

	class App(BaseModel):
		name: str = "default_name1"
		value1: int = 0
		value2: float = 0.0

	class Model(BaseModel):
		title: str = "default_title"
		count: int = 0

	app: App = App()
	model: Model = Model()

def get_widgets(c: Pyfig or dict):
    if not isinstance(c, dict):
        c = c.dict()

    widgets = []
    for k, value in c.items():
        if isinstance(value, dict):
            widgets.append(pn.pane.Markdown(f"## {k.capitalize()}"))
            widgets.extend(get_widgets(value))
            continue

        if isinstance(value, str):
            widget_type = pn.widgets.TextInput
        elif isinstance(value, int):
            widget_type = pn.widgets.IntInput
        elif isinstance(value, float):
            widget_type = pn.widgets.FloatInput
        elif isinstance(value, bool):
            widget_type = pn.widgets.Checkbox
        elif isinstance(value, list):
            widget_type = pn.widgets.TextInput
            value = ','.join([str(v) for v in value])
        else:
            widget_type = pn.widgets.TextAreaInput

        widget = widget_type(value=value, name=k)
        widgets.append(widget)

    return widgets

def build_dashboard(c: dict):
    widgets = get_widgets(c)
    print(widgets)
    dashboard = pn.Column(*widgets)
    return dashboard, c

c = Pyfig()
print('init:d ', c.dict(), sep='\n')

dashboard, c = build_dashboard(c)

dashboard
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# init:d
# {'opt': ['Adam', 'SGD'], 'float_array': [], 'test': True, 'app': {'name': 'default_name1', 'value1': 0, 'value2': 0.0}, 'model': {'title': 'default_title', 'count': 0}}
# [TextInput(name='opt', value='Adam,SGD'), TextInput(name='float_array'), IntInput(name='test', value=True), Markdown(str), TextInput(name='name', value='default_name1'), IntInput(name='value1'), FloatInput(name='value2'), Markdown(str), TextInput(name='title', value='default_title'), IntInput(name='count')]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/IPython/core/formatters.py:972, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     969     method = get_real_method(obj, self.print_method)
#     971     if method is not None:
# --> 972         return method(include=include, exclude=exclude)
#     973     return None
#     974 else:
#
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/panel/viewable.py:623, in Viewable._repr_mimebundle_(self, include, exclude)
#     620     loaded = hv.extension._loaded
#     622 if config.comms in ('vscode', 'ipywidgets'):
# --> 623     widget = ipywidget(self)
#     624     if hasattr(widget, '_repr_mimebundle_'):
#     625         return widget._repr_mimebundle_(include=include, exclude=exclude), {}
#
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/panel/io/notebook.py:384, in ipywidget(obj, **kwargs)
#     367 def ipywidget(obj: Any, **kwargs: Any):
#     368     """
#     369     Returns an ipywidget model which renders the Panel object.
#     370
#    (...)
#     382     Returns an ipywidget model which renders the Panel object.
#     383     """
# --> 384     from jupyter_bokeh.widgets import BokehModel
#     386     from ..pane import panel
#     387     model = panel(obj, **kwargs).get_root()
#
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/jupyter_bokeh/__init__.py:9
#       5 from ._version import __version__
#       7 HERE = Path(__file__).parent.resolve()
# ----> 9 from .widgets import BokehModel
#      10 with (HERE / "labextension" / "package.json").open() as fid:
#      11     data = json.load(fid)
#
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/jupyter_bokeh/widgets.py:33
#      31 from bokeh.models import ColumnDataSource, LayoutDOM
#      32 from bokeh.protocol import Protocol
# ---> 33 from bokeh.core.serialization import Deserializer, Serialized
#      34 from bokeh.model import Model
#      36 from ._version import __version__
#
# File ~/miniconda3/envs/bet/lib/python3.10/site-packages/bokeh/core/serialization.py:63
#      47 from ..util.dataclasses import (
#      48     Unspecified,
#      49     dataclass,
#      50     entries,
#      51     is_dataclass,
#      52 )
#      53 from ..util.serialization import (
#      54     array_encoding_disabled,
#      55     convert_datetime_type,
#    (...)
#      61     transform_series,
#      62 )
# ---> 63 from ..util.warnings import BokehUserWarning, warn
#      64 from .types import ID
#      66 if TYPE_CHECKING:
#
# ImportError: cannot import name 'warn' from 'bokeh.util.warnings' (/Users/xmkqv/miniconda3/envs/bet/lib/python3.10/site-packages/bokeh/util/warnings.py)
# Column
#     [0] TextInput(name='opt', value='Adam,SGD')
#     [1] TextInput(name='float_array')
#     [2] IntInput(name='test', value=True)
#     [3] Markdown(str)
#     [4] TextInput(name='name', value='default_name1')
#     [5] IntInput(name='value1')
#     [6] FloatInput(name='value2')
#     [7] Markdown(str)
#     [8] TextInput(name='title', value='default_title')
#     [9] IntInput(name='count')
