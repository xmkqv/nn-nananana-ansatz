# %%
import wandb
api = wandb.Api()
run = api.run("qm-hwat/hwat/runs/8920362.eval.15.0")
e = run.history()["exp_stats/all/e_\mu$"]

# %%
run.summary['E_mean'] = e.mean()
run.summary['E_std'] = e.std()
run.update()

# %%
run.summary['O2-triplet,CCSD(T)-F12,quadruple-z_basis_set'] = -150.198328251244
run.update()
